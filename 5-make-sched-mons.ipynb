# %%
import sys
if '/home/ec2-user/sagemaker-pipe-template' not in sys.path:
    sys.path.insert(0, '/home/ec2-user/sagemaker-pipe-template')
if '/home/ec2-user/sagemaker-pipe-template/pipeline' not in sys.path:
    sys.path.insert(0, '/home/ec2-user/sagemaker-pipe-template/pipeline')
import paths, boto3, utils
from sagemaker.core.helper.session_helper import get_execution_role, Session
from monitor_jobs import create_data_quality_monitoring_schedule, create_model_bias_monitoring_schedule, create_model_explainability_monitoring_schedule, create_model_quality_monitoring_schedule

# %%
boto_session=boto3.Session(region_name='us-east-1')
sm_client = boto_session.client('sagemaker', region_name='us-east-1')
p=paths.Paths(bucket_name='omm-test-bucket', project_name='abalone', model_prefix='abalone')
endpoint_name='abalone-endpoint'
# Out:
# [06/18/26 22:48:09] INFO     Found credentials from IAM Role: ec2-1                             ]8;id=13759090;file:///home/ec2-user/.local/lib/python3.9/site-packages/botocore/credentials.py\credentials.py]8;;\:]8;id=13759091;file:///home/ec2-user/.local/lib/python3.9/site-packages/botocore/credentials.py#1171\1171]8;;\

# %%
# MonitoringScheduleConfig
{
'ScheduleConfig':{
    'ScheduleExpression':str, 
    'DataAnalysisStartTime':str, 
    'DataAnalysisEndTime':str
}, 
'MonitoringJobDefinition':{
    'BaselineConfig':{
        'BaseliningJobName':str, 
        'ConstraintsResource':{'S3Uri':str}, 
        'StatisticsResource':{'S3Uri':str}, 
    }, 
    'MonitoringInputs':[
        {
            'EndpointInput':{
                'EndpointName':str, 
                'LocalPath':str, 
                'S3InputMode':str, 
                'S3DataDistributionType':str, 
                'FeaturesAttribute':str, 
                'InferenceAttribute':str, 
                'ProbabilityAttribute':str, 
                'ProbabilityThresholdAttribute':float, 
                'StartTimeOffset':str, 
                'EndTimeOffset':str, 
                'ExcludeFeaturesAttribute':str
            }, 
            'BatchTransformInput':{
                'DataCapturedDestinationS3Uri':str, 
                'DatasetFormat':{
                    'Csv':{'Header':str}, 
                    'Json':{'Line':str}, 
                    'Parquet':{}
                }, 
                'LocalPath':str, 
                'S3InputMode':str, 
                'S3DataDistributionType':str, 
                'FeaturesAttribute':str, 
                'InferenceAttribute':str, 
                'ProbabilityAttribute':str, 
                'ProbabilityThresholdAttribute':float, 
                'StartTimeOffset':str, 
                'EndTimeOffset':str, 
                'ExcludeFeaturesAttribute':str

            }
        },
    ], 
    'MonitoringOutputConfig':{
        'MonitoringOutputs':[
            {
                'S3Output':{
                    'S3Uri':str, 
                    'LocalPath':str, 
                    'S3UploadMode':str
                    }
            },
        ], 
        'KmsKeyId':str
    }, 
    'MonitoringResources':{
        'ClusterConfig':{
            'InstanceCount':int, 
            'InstanceType':str, 
            'VolumeSizeInGB':int, 
            'VolumeKmsKeyId':str
        }
    }, 
    'MonitoringAppSpecification':{
        'ImageUri':str, 
        'ContainerEntrypoint':[str], 
        'ContainerArguments':list[str], 
        'RecordPreprocessorSourceUri':str, 
        'PostAnalyticsProcessorSourceUri':str
    }, 
    'StoppingCondition':{'MaxRuntimeInSeconds':int}, 
    'Environment':map, 
    'NetworkConfig':{
        'EnableInterContainerTrafficEncryption':bool, 
        'EnableNetworkIsolation':bool, 
        'VpcConfig':{'SecurityGroupIds':list[str], 'Subnets':list[str]}
    }, 
    'RoleArn':str
}, 
'MonitoringJobDefinitionName':str, 
'MonitoringType':str
}
# Out:
# {'ScheduleConfig': {'ScheduleExpression': str,
#   'DataAnalysisStartTime': str,
#   'DataAnalysisEndTime': str},
#  'MonitoringJobDefinition': {'BaselineConfig': {'BaseliningJobName': str,
#    'ConstraintsResource': {'S3Uri': str},
#    'StatisticsResource': {'S3Uri': str}},
#   'MonitoringInputs': [{'EndpointInput': {'EndpointName': str,
#      'LocalPath': str,
#      'S3InputMode': str,
#      'S3DataDistributionType': str,
#      'FeaturesAttribute': str,
#      'InferenceAttribute': str,
#      'ProbabilityAttribute': str,
#      'ProbabilityThresholdAttribute': float,
#      'StartTimeOffset': str,
#      'EndTimeOffset': str,
#      'ExcludeFeaturesAttribute': str},
#     'BatchTransformInput': {'DataCapturedDestinationS3Uri': str,
#      'DatasetFormat': {'Csv': {'Header': str},
#       'Json': {'Line': str},
#       'Parquet': {}},
#      'LocalPath': str,
#      'S3InputMode': str,
#      'S3DataDistributionType': str,
#      'FeaturesAttribute': str,
#      'InferenceAttribute': str,
#      'ProbabilityAttribute': str,
#      'ProbabilityThresholdAttribute': float,
#      'StartTimeOffset': str,
#      'EndTimeOffset': str,
#      'ExcludeFeaturesAttribute': str}}],
#   'MonitoringOutputConfig': {'MonitoringOutputs': [{'S3Output': {'S3Uri': str,
#       'LocalPath': str,
#       'S3UploadMode': str}}],
#    'KmsKeyId': str},
#   'MonitoringResources': {'ClusterConfig': {'InstanceCount': int,
#     'InstanceType': str,
#     'VolumeSizeInGB': int,
#     'VolumeKmsKeyId': str}},
#   'MonitoringAppSpecification': {'ImageUri': str,
#    'ContainerEntrypoint': [str],
#    'ContainerArguments': list[str],
#    'RecordPreprocessorSourceUri': str,
#    'PostAnalyticsProcessorSourceUri': str},
#   'StoppingCondition': {'MaxRuntimeInSeconds': int},
#   'Environment': map,
#   'NetworkConfig': {'EnableInterContainerTrafficEncryption': bool,
#    'EnableNetworkIsolation': bool,
#    'VpcConfig': {'SecurityGroupIds': list[str], 'Subnets': list[str]}},
#   'RoleArn': str},
#  'MonitoringJobDefinitionName': str,
#  'MonitoringType': str}

# %%
create_data_quality_monitoring_schedule(
    sm_client, 
    'dq-mon',
    get_execution_role(),
    'realtime',
    p.dq_monitor_dir,
    'cron(0 * ? * * *)', 
    "-PT2H", 
    "-PT1H",
    endpoint_name=endpoint_name
)
# Out:
# [06/18/26 23:01:11] INFO     Found credentials from IAM Role: ec2-1                             ]8;id=13759126;file:///home/ec2-user/.local/lib/python3.9/site-packages/botocore/credentials.py\credentials.py]8;;\:]8;id=13759127;file:///home/ec2-user/.local/lib/python3.9/site-packages/botocore/credentials.py#1171\1171]8;;\
# {'MonitoringScheduleArn': 'arn:aws:sagemaker:us-east-1:088461143167:monitoring-schedule/dq-mon',
#  'ResponseMetadata': {'RequestId': '8b86ebaf-b229-4c7f-9a2c-98d68ce682ac',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '8b86ebaf-b229-4c7f-9a2c-98d68ce682ac',
#    'strict-transport-security': 'max-age=47304000; includeSubDomains',
#    'x-frame-options': 'DENY',
#    'content-security-policy': "frame-ancestors 'none'",
#    'cache-control': 'no-cache, no-store, must-revalidate',
#    'x-content-type-options': 'nosniff',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '95',
#    'date': 'Thu, 18 Jun 2026 23:01:13 GMT'},
#   'RetryAttempts': 0}}

# %%
create_model_bias_monitoring_schedule(
    sm_client, 
    'mb-mon',
    get_execution_role(),
    'realtime',
    p.mb_monitor_dir,
    p.ground_truth_dir,
    'cron(0 * ? * * *)', 
    "-PT2H", 
    "-PT1H",
    endpoint_name=endpoint_name
)
# Out:
# [06/18/26 23:01:15] INFO     Found credentials from IAM Role: ec2-1                             ]8;id=13759132;file:///home/ec2-user/.local/lib/python3.9/site-packages/botocore/credentials.py\credentials.py]8;;\:]8;id=13759133;file:///home/ec2-user/.local/lib/python3.9/site-packages/botocore/credentials.py#1171\1171]8;;\
# {'MonitoringScheduleArn': 'arn:aws:sagemaker:us-east-1:088461143167:monitoring-schedule/mb-mon',
#  'ResponseMetadata': {'RequestId': '6c621877-31d7-4eb2-be0b-48739e0d1463',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '6c621877-31d7-4eb2-be0b-48739e0d1463',
#    'strict-transport-security': 'max-age=47304000; includeSubDomains',
#    'x-frame-options': 'DENY',
#    'content-security-policy': "frame-ancestors 'none'",
#    'cache-control': 'no-cache, no-store, must-revalidate',
#    'x-content-type-options': 'nosniff',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '95',
#    'date': 'Thu, 18 Jun 2026 23:01:17 GMT'},
#   'RetryAttempts': 0}}

# %%
create_model_explainability_monitoring_schedule(
    sm_client, 
    'me-mon',
    get_execution_role(),
    'realtime',
    p.me_monitor_dir,
    'cron(0 * ? * * *)', 
    "-PT2H", 
    "-PT1H",
    endpoint_name=endpoint_name
)
# Out:
# [06/18/26 23:01:18] INFO     Found credentials from IAM Role: ec2-1                             ]8;id=13759138;file:///home/ec2-user/.local/lib/python3.9/site-packages/botocore/credentials.py\credentials.py]8;;\:]8;id=13759139;file:///home/ec2-user/.local/lib/python3.9/site-packages/botocore/credentials.py#1171\1171]8;;\
# {'MonitoringScheduleArn': 'arn:aws:sagemaker:us-east-1:088461143167:monitoring-schedule/me-mon',
#  'ResponseMetadata': {'RequestId': '0de4c46e-f666-4e16-81cc-39ee285aad3f',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '0de4c46e-f666-4e16-81cc-39ee285aad3f',
#    'strict-transport-security': 'max-age=47304000; includeSubDomains',
#    'x-frame-options': 'DENY',
#    'content-security-policy': "frame-ancestors 'none'",
#    'cache-control': 'no-cache, no-store, must-revalidate',
#    'x-content-type-options': 'nosniff',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '95',
#    'date': 'Thu, 18 Jun 2026 23:01:20 GMT'},
#   'RetryAttempts': 0}}

# %%
create_model_quality_monitoring_schedule(
    sm_client, 
    'mq-mon',
    get_execution_role(),
    'realtime',
    'Regression',
    'rings_prediction',
    p.mq_monitor_dir,
    p.ground_truth_dir,
    'cron(0 * ? * * *)', 
    "-PT2H", 
    "-PT1H",
    endpoint_name=endpoint_name
)
# Out:
# [06/18/26 23:01:22] INFO     Found credentials from IAM Role: ec2-1                             ]8;id=13759144;file:///home/ec2-user/.local/lib/python3.9/site-packages/botocore/credentials.py\credentials.py]8;;\:]8;id=13759145;file:///home/ec2-user/.local/lib/python3.9/site-packages/botocore/credentials.py#1171\1171]8;;\
# {'MonitoringScheduleArn': 'arn:aws:sagemaker:us-east-1:088461143167:monitoring-schedule/mq-mon',
#  'ResponseMetadata': {'RequestId': 'afddf4d4-7f21-4324-bc36-02fd055329af',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': 'afddf4d4-7f21-4324-bc36-02fd055329af',
#    'strict-transport-security': 'max-age=47304000; includeSubDomains',
#    'x-frame-options': 'DENY',
#    'content-security-policy': "frame-ancestors 'none'",
#    'cache-control': 'no-cache, no-store, must-revalidate',
#    'x-content-type-options': 'nosniff',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '95',
#    'date': 'Thu, 18 Jun 2026 23:01:23 GMT'},
#   'RetryAttempts': 0}}
