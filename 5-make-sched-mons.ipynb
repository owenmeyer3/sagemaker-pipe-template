# %%
import sys
if '/home/ec2-user/sagemaker-pipe-template' not in sys.path:
    sys.path.insert(0, '/home/ec2-user/sagemaker-pipe-template')
if '/home/ec2-user/sagemaker-pipe-template/pipeline' not in sys.path:
    sys.path.insert(0, '/home/ec2-user/sagemaker-pipe-template/pipeline')
import paths, boto3, utils
from sagemaker.core.helper.session_helper import get_execution_role, Session
from monitor_jobs import create_data_quality_monitoring_schedule, create_model_bias_monitoring_schedule, create_model_explainability_monitoring_schedule, create_model_quality_monitoring_schedule

# %%
boto_session=boto3.Session(region_name='us-east-1')
sm_client = boto_session.client('sagemaker', region_name='us-east-1')
p=paths.Paths(bucket_name='omm-test-bucket', project_name='abalone', model_prefix='abalone')
endpoint_name='abalone-endpoint'
# Out:
# [06/18/26 22:48:09] INFO     Found credentials from IAM Role: ec2-1                             ]8;id=13759090;file:///home/ec2-user/.local/lib/python3.9/site-packages/botocore/credentials.py\credentials.py]8;;\:]8;id=13759091;file:///home/ec2-user/.local/lib/python3.9/site-packages/botocore/credentials.py#1171\1171]8;;\

# %%
# MonitoringScheduleConfig
{
'ScheduleConfig':{
    'ScheduleExpression':str, 
    'DataAnalysisStartTime':str, 
    'DataAnalysisEndTime':str
}, 
'MonitoringJobDefinition':{
    'BaselineConfig':{
        'BaseliningJobName':str, 
        'ConstraintsResource':{'S3Uri':str}, 
        'StatisticsResource':{'S3Uri':str}, 
    }, 
    'MonitoringInputs':[
        {
            'EndpointInput':{
                'EndpointName':str, 
                'LocalPath':str, 
                'S3InputMode':str, 
                'S3DataDistributionType':str, 
                'FeaturesAttribute':str, 
                'InferenceAttribute':str, 
                'ProbabilityAttribute':str, 
                'ProbabilityThresholdAttribute':float, 
                'StartTimeOffset':str, 
                'EndTimeOffset':str, 
                'ExcludeFeaturesAttribute':str
            }, 
            'BatchTransformInput':{
                'DataCapturedDestinationS3Uri':str, 
                'DatasetFormat':{
                    'Csv':{'Header':str}, 
                    'Json':{'Line':str}, 
                    'Parquet':{}
                }, 
                'LocalPath':str, 
                'S3InputMode':str, 
                'S3DataDistributionType':str, 
                'FeaturesAttribute':str, 
                'InferenceAttribute':str, 
                'ProbabilityAttribute':str, 
                'ProbabilityThresholdAttribute':float, 
                'StartTimeOffset':str, 
                'EndTimeOffset':str, 
                'ExcludeFeaturesAttribute':str

            }
        },
    ], 
    'MonitoringOutputConfig':{
        'MonitoringOutputs':[
            {
                'S3Output':{
                    'S3Uri':str, 
                    'LocalPath':str, 
                    'S3UploadMode':str
                    }
            },
        ], 
        'KmsKeyId':str
    }, 
    'MonitoringResources':{
        'ClusterConfig':{
            'InstanceCount':int, 
            'InstanceType':str, 
            'VolumeSizeInGB':int, 
            'VolumeKmsKeyId':str
        }
    }, 
    'MonitoringAppSpecification':{
        'ImageUri':str, 
        'ContainerEntrypoint':[str], 
        'ContainerArguments':list[str], 
        'RecordPreprocessorSourceUri':str, 
        'PostAnalyticsProcessorSourceUri':str
    }, 
    'StoppingCondition':{'MaxRuntimeInSeconds':int}, 
    'Environment':map, 
    'NetworkConfig':{
        'EnableInterContainerTrafficEncryption':bool, 
        'EnableNetworkIsolation':bool, 
        'VpcConfig':{'SecurityGroupIds':list[str], 'Subnets':list[str]}
    }, 
    'RoleArn':str
}, 
'MonitoringJobDefinitionName':str, 
'MonitoringType':str
}
# Out:
# {'ScheduleConfig': {'ScheduleExpression': str,
#   'DataAnalysisStartTime': str,
#   'DataAnalysisEndTime': str},
#  'MonitoringJobDefinition': {'BaselineConfig': {'BaseliningJobName': str,
#    'ConstraintsResource': {'S3Uri': str},
#    'StatisticsResource': {'S3Uri': str}},
#   'MonitoringInputs': [{'EndpointInput': {'EndpointName': str,
#      'LocalPath': str,
#      'S3InputMode': str,
#      'S3DataDistributionType': str,
#      'FeaturesAttribute': str,
#      'InferenceAttribute': str,
#      'ProbabilityAttribute': str,
#      'ProbabilityThresholdAttribute': float,
#      'StartTimeOffset': str,
#      'EndTimeOffset': str,
#      'ExcludeFeaturesAttribute': str},
#     'BatchTransformInput': {'DataCapturedDestinationS3Uri': str,
#      'DatasetFormat': {'Csv': {'Header': str},
#       'Json': {'Line': str},
#       'Parquet': {}},
#      'LocalPath': str,
#      'S3InputMode': str,
#      'S3DataDistributionType': str,
#      'FeaturesAttribute': str,
#      'InferenceAttribute': str,
#      'ProbabilityAttribute': str,
#      'ProbabilityThresholdAttribute': float,
#      'StartTimeOffset': str,
#      'EndTimeOffset': str,
#      'ExcludeFeaturesAttribute': str}}],
#   'MonitoringOutputConfig': {'MonitoringOutputs': [{'S3Output': {'S3Uri': str,
#       'LocalPath': str,
#       'S3UploadMode': str}}],
#    'KmsKeyId': str},
#   'MonitoringResources': {'ClusterConfig': {'InstanceCount': int,
#     'InstanceType': str,
#     'VolumeSizeInGB': int,
#     'VolumeKmsKeyId': str}},
#   'MonitoringAppSpecification': {'ImageUri': str,
#    'ContainerEntrypoint': [str],
#    'ContainerArguments': list[str],
#    'RecordPreprocessorSourceUri': str,
#    'PostAnalyticsProcessorSourceUri': str},
#   'StoppingCondition': {'MaxRuntimeInSeconds': int},
#   'Environment': map,
#   'NetworkConfig': {'EnableInterContainerTrafficEncryption': bool,
#    'EnableNetworkIsolation': bool,
#    'VpcConfig': {'SecurityGroupIds': list[str], 'Subnets': list[str]}},
#   'RoleArn': str},
#  'MonitoringJobDefinitionName': str,
#  'MonitoringType': str}

# %%
schedules = sm_client.list_monitoring_schedules(EndpointName=endpoint_name)
for schedule in schedules['MonitoringScheduleSummaries']:
    print(f"schedule: {schedule['MonitoringScheduleName']}")
# Out:
# schedule: dq-mon
# schedule: mq-mon
# schedule: data-quality-monitor

# %%
create_data_quality_monitoring_schedule(
    sm_client, 
    'dq-mon',
    get_execution_role(),
    'realtime',
    p.dq_monitor_dir,
    'cron(0 * ? * * *)', 
    "-PT2H", 
    "-PT1H",
    endpoint_name=endpoint_name
)
# Out:
# [06/18/26 22:48:10] INFO     Found credentials from IAM Role: ec2-1                             ]8;id=13759096;file:///home/ec2-user/.local/lib/python3.9/site-packages/botocore/credentials.py\credentials.py]8;;\:]8;id=13759097;file:///home/ec2-user/.local/lib/python3.9/site-packages/botocore/credentials.py#1171\1171]8;;\
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:1                                                                                    │
# │                                                                                                  │
# │ ❱  1 create_data_quality_monitoring_schedule(                                                    │
# │    2 │   sm_client,                                                                              │
# │    3 │   'dq-mon',                                                                               │
# │    4 │   get_execution_role(),                                                                   │
# │                                                                                                  │
# │ /home/ec2-user/sagemaker-pipe-template/pipeline/monitor_jobs.py:411 in                           │
# │ create_data_quality_monitoring_schedule                                                          │
# │                                                                                                  │
# │   408 │                                                                                          │
# │   409 │   job_definition_name = f'{name}-job'                                                    │
# │   410 │                                                                                          │
# │ ❱ 411 │   response = create_data_quality_job_definition(                                         │
# │   412 │   │   sm_client,                                                                         │
# │   413 │   │   role,                                                                              │
# │   414 │   │   job_definition_name,                                                               │
# │                                                                                                  │
# │ /home/ec2-user/sagemaker-pipe-template/pipeline/monitor_jobs.py:50 in                            │
# │ create_data_quality_job_definition                                                               │
# │                                                                                                  │
# │    47 │   │   │   }                                                                              │
# │    48 │   │   }                                                                                  │
# │    49 │                                                                                          │
# │ ❱  50 │   response = sm_client.create_data_quality_job_definition(                               │
# │    51 │   │   JobDefinitionName=name,                                                            │
# │    52 │   │   DataQualityBaselineConfig={                                                        │
# │    53 │   │   │   #'BaseliningJobName': 'string',                                                │
# │                                                                                                  │
# │ /home/ec2-user/.local/lib/python3.9/site-packages/botocore/client.py:606 in _api_call            │
# │                                                                                                  │
# │    603 │   │   │   │   │   f"{py_operation_name}() only accepts keyword arguments."              │
# │    604 │   │   │   │   )                                                                         │
# │    605 │   │   │   # The "self" in this scope is referring to the BaseClient.                    │
# │ ❱  606 │   │   │   return self._make_api_call(operation_name, kwargs)                            │
# │    607 │   │                                                                                     │
# │    608 │   │   _api_call.__name__ = str(py_operation_name)                                       │
# │    609                                                                                           │
# │                                                                                                  │
# │ /home/ec2-user/.local/lib/python3.9/site-packages/botocore/context.py:123 in wrapper             │
# │                                                                                                  │
# │   120 │   │   │   with start_as_current_context():                                               │
# │   121 │   │   │   │   if hook:                                                                   │
# │   122 │   │   │   │   │   hook()                                                                 │
# │ ❱ 123 │   │   │   │   return func(*args, **kwargs)                                               │
# │   124 │   │                                                                                      │
# │   125 │   │   return wrapper                                                                     │
# │   126                                                                                            │
# │                                                                                                  │
# │ /home/ec2-user/.local/lib/python3.9/site-packages/botocore/client.py:1094 in _make_api_call      │
# │                                                                                                  │
# │   1091 │   │   │   │   'error_code_override'                                                     │
# │   1092 │   │   │   ) or error_info.get("Code")                                                   │
# │   1093 │   │   │   error_class = self.exceptions.from_code(error_code)                           │
# │ ❱ 1094 │   │   │   raise error_class(parsed_response, operation_name)                            │
# │   1095 │   │   else:                                                                             │
# │   1096 │   │   │   return parsed_response                                                        │
# │   1097                                                                                           │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ResourceInUse: An error occurred (ResourceInUse) when calling the CreateDataQualityJobDefinition operation:
# Monitoring Job Definition arn:aws:sagemaker:us-east-1:088461143167:data-quality-job-definition/dq-mon-job already
# exists

# %%
create_model_bias_monitoring_schedule(
    sm_client, 
    'mb-mon',
    get_execution_role(),
    'realtime',
    p.mb_monitor_dir,
    p.ground_truth_dir,
    'cron(0 * ? * * *)', 
    "-PT2H", 
    "-PT1H",
    endpoint_name=endpoint_name
)
# Out:
# [06/18/26 22:48:18] INFO     Found credentials from IAM Role: ec2-1                             ]8;id=13759102;file:///home/ec2-user/.local/lib/python3.9/site-packages/botocore/credentials.py\credentials.py]8;;\:]8;id=13759103;file:///home/ec2-user/.local/lib/python3.9/site-packages/botocore/credentials.py#1171\1171]8;;\
# {'MonitoringScheduleArn': 'arn:aws:sagemaker:us-east-1:088461143167:monitoring-schedule/mb-mon',
#  'ResponseMetadata': {'RequestId': '085accf9-eee5-4141-9a91-48bb05fdf5fb',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '085accf9-eee5-4141-9a91-48bb05fdf5fb',
#    'strict-transport-security': 'max-age=47304000; includeSubDomains',
#    'x-frame-options': 'DENY',
#    'content-security-policy': "frame-ancestors 'none'",
#    'cache-control': 'no-cache, no-store, must-revalidate',
#    'x-content-type-options': 'nosniff',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '95',
#    'date': 'Thu, 18 Jun 2026 22:48:19 GMT'},
#   'RetryAttempts': 0}}

# %%
create_model_explainability_monitoring_schedule(
    sm_client, 
    'me-mon',
    get_execution_role(),
    'realtime',
    p.me_monitor_dir,
    'cron(0 * ? * * *)', 
    "-PT2H", 
    "-PT1H",
    endpoint_name=endpoint_name
)
# Out:
# [06/18/26 22:48:22] INFO     Found credentials from IAM Role: ec2-1                             ]8;id=13759108;file:///home/ec2-user/.local/lib/python3.9/site-packages/botocore/credentials.py\credentials.py]8;;\:]8;id=13759109;file:///home/ec2-user/.local/lib/python3.9/site-packages/botocore/credentials.py#1171\1171]8;;\
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:1                                                                                    │
# │                                                                                                  │
# │ ❱  1 create_model_explainability_monitoring_schedule(                                            │
# │    2 │   sm_client,                                                                              │
# │    3 │   'me-mon',                                                                               │
# │    4 │   get_execution_role(),                                                                   │
# │                                                                                                  │
# │ /home/ec2-user/sagemaker-pipe-template/pipeline/monitor_jobs.py:516 in                           │
# │ create_model_explainability_monitoring_schedule                                                  │
# │                                                                                                  │
# │   513 │   │   dataset_format={'Csv': {'Header': True}} # {'Csv':{'Header': True|False},'Json':   │
# │   514 │   )                                                                                      │
# │   515 │                                                                                          │
# │ ❱ 516 │   response = sm_client.create_monitoring_schedule(                                       │
# │   517 │   │   MonitoringScheduleName=name,                                                       │
# │   518 │   │   MonitoringScheduleConfig={                                                         │
# │   519 │   │   │   'ScheduleConfig': {                                                            │
# │                                                                                                  │
# │ /home/ec2-user/.local/lib/python3.9/site-packages/botocore/client.py:606 in _api_call            │
# │                                                                                                  │
# │    603 │   │   │   │   │   f"{py_operation_name}() only accepts keyword arguments."              │
# │    604 │   │   │   │   )                                                                         │
# │    605 │   │   │   # The "self" in this scope is referring to the BaseClient.                    │
# │ ❱  606 │   │   │   return self._make_api_call(operation_name, kwargs)                            │
# │    607 │   │                                                                                     │
# │    608 │   │   _api_call.__name__ = str(py_operation_name)                                       │
# │    609                                                                                           │
# │                                                                                                  │
# │ /home/ec2-user/.local/lib/python3.9/site-packages/botocore/context.py:123 in wrapper             │
# │                                                                                                  │
# │   120 │   │   │   with start_as_current_context():                                               │
# │   121 │   │   │   │   if hook:                                                                   │
# │   122 │   │   │   │   │   hook()                                                                 │
# │ ❱ 123 │   │   │   │   return func(*args, **kwargs)                                               │
# │   124 │   │                                                                                      │
# │   125 │   │   return wrapper                                                                     │
# │   126                                                                                            │
# │                                                                                                  │
# │ /home/ec2-user/.local/lib/python3.9/site-packages/botocore/client.py:1094 in _make_api_call      │
# │                                                                                                  │
# │   1091 │   │   │   │   'error_code_override'                                                     │
# │   1092 │   │   │   ) or error_info.get("Code")                                                   │
# │   1093 │   │   │   error_class = self.exceptions.from_code(error_code)                           │
# │ ❱ 1094 │   │   │   raise error_class(parsed_response, operation_name)                            │
# │   1095 │   │   else:                                                                             │
# │   1096 │   │   │   return parsed_response                                                        │
# │   1097                                                                                           │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ResourceLimitExceeded: An error occurred (ResourceLimitExceeded) when calling the CreateMonitoringSchedule
# operation: The account-level service limit 'ml.m5.large for processing job usage' is 4 Instances, with current
# utilization of 4 Instances and a request delta of 1 Instances. Please use AWS Service Quotas to request an increase
# for this quota. If AWS Service Quotas is not available, contact AWS support to request an increase for this quota.

# %%
create_model_quality_monitoring_schedule(
    sm_client, 
    'mq-mon',
    get_execution_role(),
    'realtime',
    'Regression',
    'rings_prediction',
    p.mq_monitor_dir,
    p.ground_truth_dir,
    'cron(0 * ? * * *)', 
    "-PT2H", 
    "-PT1H",
    endpoint_name=endpoint_name
)
# Out:
# [06/18/26 22:48:27] INFO     Found credentials from IAM Role: ec2-1                             ]8;id=13759114;file:///home/ec2-user/.local/lib/python3.9/site-packages/botocore/credentials.py\credentials.py]8;;\:]8;id=13759115;file:///home/ec2-user/.local/lib/python3.9/site-packages/botocore/credentials.py#1171\1171]8;;\
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:1                                                                                    │
# │                                                                                                  │
# │ ❱  1 create_model_quality_monitoring_schedule(                                                   │
# │    2 │   sm_client,                                                                              │
# │    3 │   'mq-mon',                                                                               │
# │    4 │   get_execution_role(),                                                                   │
# │                                                                                                  │
# │ /home/ec2-user/sagemaker-pipe-template/pipeline/monitor_jobs.py:566 in                           │
# │ create_model_quality_monitoring_schedule                                                         │
# │                                                                                                  │
# │   563 │   │   dataset_format={'Csv': {'Header': True}} # {'Csv':{'Header': True|False},'Json':   │
# │   564 │   )                                                                                      │
# │   565 │                                                                                          │
# │ ❱ 566 │   response = sm_client.create_monitoring_schedule(                                       │
# │   567 │   │   MonitoringScheduleName=name,                                                       │
# │   568 │   │   MonitoringScheduleConfig={                                                         │
# │   569 │   │   │   'ScheduleConfig': {                                                            │
# │                                                                                                  │
# │ /home/ec2-user/.local/lib/python3.9/site-packages/botocore/client.py:606 in _api_call            │
# │                                                                                                  │
# │    603 │   │   │   │   │   f"{py_operation_name}() only accepts keyword arguments."              │
# │    604 │   │   │   │   )                                                                         │
# │    605 │   │   │   # The "self" in this scope is referring to the BaseClient.                    │
# │ ❱  606 │   │   │   return self._make_api_call(operation_name, kwargs)                            │
# │    607 │   │                                                                                     │
# │    608 │   │   _api_call.__name__ = str(py_operation_name)                                       │
# │    609                                                                                           │
# │                                                                                                  │
# │ /home/ec2-user/.local/lib/python3.9/site-packages/botocore/context.py:123 in wrapper             │
# │                                                                                                  │
# │   120 │   │   │   with start_as_current_context():                                               │
# │   121 │   │   │   │   if hook:                                                                   │
# │   122 │   │   │   │   │   hook()                                                                 │
# │ ❱ 123 │   │   │   │   return func(*args, **kwargs)                                               │
# │   124 │   │                                                                                      │
# │   125 │   │   return wrapper                                                                     │
# │   126                                                                                            │
# │                                                                                                  │
# │ /home/ec2-user/.local/lib/python3.9/site-packages/botocore/client.py:1094 in _make_api_call      │
# │                                                                                                  │
# │   1091 │   │   │   │   'error_code_override'                                                     │
# │   1092 │   │   │   ) or error_info.get("Code")                                                   │
# │   1093 │   │   │   error_class = self.exceptions.from_code(error_code)                           │
# │ ❱ 1094 │   │   │   raise error_class(parsed_response, operation_name)                            │
# │   1095 │   │   else:                                                                             │
# │   1096 │   │   │   return parsed_response                                                        │
# │   1097                                                                                           │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ResourceLimitExceeded: An error occurred (ResourceLimitExceeded) when calling the CreateMonitoringSchedule
# operation: The account-level service limit 'ml.m5.large for processing job usage' is 4 Instances, with current
# utilization of 4 Instances and a request delta of 1 Instances. Please use AWS Service Quotas to request an increase
# for this quota. If AWS Service Quotas is not available, contact AWS support to request an increase for this quota.
